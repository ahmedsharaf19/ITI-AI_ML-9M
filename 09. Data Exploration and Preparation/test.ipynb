# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.39.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting urllib3<3.0,>=2.5.0 (from urllib3[socks]<3.0,>=2.5.0->selenium)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Using cached trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.10.5 in c:\users\ahmed\anaconda3\lib\site-packages (from selenium) (2025.10.5)
# Collecting typing_extensions<5.0,>=4.15.0 (from selenium)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\ahmed\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\ahmed\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\ahmed\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\ahmed\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\ahmed\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\ahmed\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Using cached wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ahmed\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\ahmed\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\ahmed\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Using cached selenium-4.39.0-py3-none-any.whl (9.7 MB)
# Using cached trio-0.32.0-py3-none-any.whl (512 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached wsproto-1.3.2-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, typing_extensions, outcome, trio, trio-websocket, selenium
#
#   Attempting uninstall: urllib3
#
#     Found existing installation: urllib3 2.3.0
#
#     Uninstalling urllib3-2.3.0:
#
#    ----- ---------------------------------- 1/7 [urllib3]
#       Successfully uninstalled urllib3-2.3.0
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#   Attempting uninstall: typing_extensions
#    ----- ---------------------------------- 1/7 [urllib3]
#     Found existing installation: typing_extensions 4.12.2
#    ----- ---------------------------------- 1/7 [urllib3]
#     Uninstalling typing_extensions-4.12.2:
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------------- 7/7 [selenium]
#
# Successfully installed outcome-1.3.0.post0 selenium-4.39.0 trio-0.32.0 trio-websocket-0.12.2 typing_extensions-4.15.0 urllib3-2.6.2 wsproto-1.3.2

# %%
from selenium import webdriver 
 
driver = webdriver.Chrome()

# %%
URL = "https://www.amazon.in/gp/bestsellers/books/"
driver.get(URL)
