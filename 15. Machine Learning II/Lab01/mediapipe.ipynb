# %%
# !pip install mediapipe==0.10.26
# Out:
# ERROR: Could not find a version that satisfies the requirement mediapipe==0.10.26 (from versions: 0.10.30, 0.10.31, 0.10.32)
# ERROR: No matching distribution found for mediapipe==0.10.26

# %%
print(mp.__version__)
# Out:
# 0.10.30

# %%
# !pip uninstall -y mediapipe
# Out:
# WARNING: Skipping mediapipe as it is not installed.

# %%
import mediapipe as mp

# %%
# !pip install mediapipe.solutions
# Out:
# ERROR: Could not find a version that satisfies the requirement mediapipe.solutions (from versions: none)
# ERROR: No matching distribution found for mediapipe.solutions

# %%
import sys
print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
import cv2
import mediapipe as mp

mp_hands = mp.solutions.hands
hands = mp_hands.Hands()
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convert to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(image)
    
    # Draw landmarks
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    
    cv2.imshow('Hand Tracking', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import cv2
#       2 import mediapipe as mp
# ----> 4 mp_hands = mp.solutions.hands
#       5 hands = mp_hands.Hands()
#       6 mp_drawing = mp.solutions.drawing_utils
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'
