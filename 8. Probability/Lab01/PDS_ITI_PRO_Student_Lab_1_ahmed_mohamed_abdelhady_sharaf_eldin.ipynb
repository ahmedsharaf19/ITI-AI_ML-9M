# %% [markdown]
# # LAB 1: Probability Concepts, Indepdenece and Random Variables
#
# In this lab you will use python to study the following topics:
#
# - How to simulate random experiment outcomes using numpy arrays.
# - How to estimate the probability of an event using the relative frequency approach.
# - Simulate independent events.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for a dataset.
# - Calculate covariance and correlation coeffecient of two random variables.

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

# matplotlib library
import matplotlib.pyplot as plt

import pandas as pd

np.random.seed(1)

# %% [markdown]
# # Problem 1
#
# Use numpy to simulate the vector outcomes for repeating the following random experiments $1000$ times and use the relative frequency to compute the probability of the corresponding events:
#
# 1. **Experiment:** Flipping a fair coin, **Event:** A head occurs.
#
# Observe how changing the number of repetition affects the computed probabilities.
#
# **Hints:**
# - Use [numpy.random.randint](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html) or [numpy.random.choice](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html) to simulate the experiment.
# - Other useful functions [numpy.arange](https://numpy.org/doc/stable/reference/generated/numpy.arange.html), [numpy.cumsum](https://numpy.org/doc/stable/reference/generated/numpy.cumsum.html), [numpy.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html), and [matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
# H -> 1
# T -> 0
trials = [10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000]
for n in trials:
    head_occ = np.sum(np.random.randint(0, 2, size = n) == 1)
    prob = head_occ / n
    print(f"n = {n}, P(e) = {prob}")
    print('-' * 50)

probs = np.cumsum(np.random.randint(0, 2, size = 1000)) / np.arange(1, 1001)
plt.plot(probs)
plt.axhline(0.5, color = 'r')
plt.grid()
# Out:
# n = 10, P(e) = 0.7
# --------------------------------------------------
# n = 50, P(e) = 0.5
# --------------------------------------------------
# n = 100, P(e) = 0.54
# --------------------------------------------------
# n = 500, P(e) = 0.448
# --------------------------------------------------
# n = 1000, P(e) = 0.502
# --------------------------------------------------
# n = 5000, P(e) = 0.5014
# --------------------------------------------------
# n = 10000, P(e) = 0.4971
# --------------------------------------------------
# n = 50000, P(e) = 0.501
# --------------------------------------------------
# n = 100000, P(e) = 0.4978
# --------------------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.52
# -----------------------------------------
# n = 500, P(e) = 0.498
# -----------------------------------------
# n = 1000, P(e) = 0.475
# -----------------------------------------
# n = 5000, P(e) = 0.4998
# -----------------------------------------
# n = 10000, P(e) = 0.5022
# -----------------------------------------
# n = 50000, P(e) = 0.5011
# -----------------------------------------
# n = 100000, P(e) = 0.49788
# -----------------------------------------

# %% [markdown]
# 2. **Experiment:** Rolling a fair die, **Event:** Number 5 occurs.

# %%
trials = [10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000]
for n in trials:
    five_occ = np.sum(np.random.randint(1, 7, size = n) == 5)
    prob = five_occ / n
    print(f"n = {n}, P(e) = {prob}")
    print('-' * 50)

probs = np.cumsum(np.random.randint(1, 7, size = 1000) == 5) / np.arange(1, 1001)
plt.plot(probs)
plt.axhline(1/6, color = 'r')
plt.grid()
# Out:
# n = 10, P(e) = 0.2
# --------------------------------------------------
# n = 50, P(e) = 0.18
# --------------------------------------------------
# n = 100, P(e) = 0.11
# --------------------------------------------------
# n = 500, P(e) = 0.18
# --------------------------------------------------
# n = 1000, P(e) = 0.179
# --------------------------------------------------
# n = 5000, P(e) = 0.1618
# --------------------------------------------------
# n = 10000, P(e) = 0.1659
# --------------------------------------------------
# n = 50000, P(e) = 0.16686
# --------------------------------------------------
# n = 100000, P(e) = 0.16953
# --------------------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.2
# -----------------------------------------
# n = 50, P(e) = 0.12
# -----------------------------------------
# n = 100, P(e) = 0.19
# -----------------------------------------
# n = 500, P(e) = 0.166
# -----------------------------------------
# n = 1000, P(e) = 0.151
# -----------------------------------------
# n = 5000, P(e) = 0.1648
# -----------------------------------------
# n = 10000, P(e) = 0.1663
# -----------------------------------------
# n = 50000, P(e) = 0.1661
# -----------------------------------------
# n = 100000, P(e) = 0.16817
# -----------------------------------------

# %% [markdown]
# 3. **Experiment:** Rolling a fair die, **Event:** A number greater than 3 occurs.

# %%
trials = [10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000]
for n in trials:
    greater_3_occ = np.sum(np.random.randint(1, 7, size = n) > 3)
    prob = greater_3_occ / n
    print(f"n = {n}, P(e) = {prob}")
    print('-' * 50)

probs = np.cumsum(np.random.randint(1, 7, size = 1000) > 3) / np.arange(1, 1001)
plt.plot(probs)
plt.axhline(3/6, color = 'r')
plt.grid()
# Out:
# n = 10, P(e) = 0.4
# --------------------------------------------------
# n = 50, P(e) = 0.38
# --------------------------------------------------
# n = 100, P(e) = 0.61
# --------------------------------------------------
# n = 500, P(e) = 0.498
# --------------------------------------------------
# n = 1000, P(e) = 0.488
# --------------------------------------------------
# n = 5000, P(e) = 0.4994
# --------------------------------------------------
# n = 10000, P(e) = 0.5031
# --------------------------------------------------
# n = 50000, P(e) = 0.50212
# --------------------------------------------------
# n = 100000, P(e) = 0.5033
# --------------------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.44
# -----------------------------------------
# n = 500, P(e) = 0.496
# -----------------------------------------
# n = 1000, P(e) = 0.489
# -----------------------------------------
# n = 5000, P(e) = 0.5052
# -----------------------------------------
# n = 10000, P(e) = 0.4962
# -----------------------------------------
# n = 50000, P(e) = 0.49842
# -----------------------------------------
# n = 100000, P(e) = 0.49983
# -----------------------------------------

# %% [markdown]
# 4. **Experiment:** Rolling two fair dice, **Event:** Sum of two dice equal 5.

# %%
trials = [10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000]
for n in trials:
    sum_5_occ = np.sum(np.sum(np.random.randint(1, 7, size = (n, 2)), axis = 1) == 5)
    prob = sum_5_occ / n
    print(f"n = {n}, P(e) = {prob}")
    print('-' * 50)

probs = np.cumsum(np.sum(np.random.randint(1, 7, size = (1000, 2)), axis = 1) == 5) / np.arange(1, 1001)
plt.plot(probs)
plt.axhline(0.111, color = 'r')
plt.grid()
# Out:
# n = 10, P(e) = 0.0
# --------------------------------------------------
# n = 50, P(e) = 0.1
# --------------------------------------------------
# n = 100, P(e) = 0.12
# --------------------------------------------------
# n = 500, P(e) = 0.112
# --------------------------------------------------
# n = 1000, P(e) = 0.126
# --------------------------------------------------
# n = 5000, P(e) = 0.1052
# --------------------------------------------------
# n = 10000, P(e) = 0.1148
# --------------------------------------------------
# n = 50000, P(e) = 0.11014
# --------------------------------------------------
# n = 100000, P(e) = 0.11091
# --------------------------------------------------

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.1
# -----------------------------------------
# n = 50, P(e) = 0.04
# -----------------------------------------
# n = 100, P(e) = 0.11
# -----------------------------------------
# n = 500, P(e) = 0.116
# -----------------------------------------
# n = 1000, P(e) = 0.112
# -----------------------------------------
# n = 5000, P(e) = 0.1134
# -----------------------------------------
# n = 10000, P(e) = 0.1056
# -----------------------------------------
# n = 50000, P(e) = 0.10812
# -----------------------------------------
# n = 100000, P(e) = 0.10955
# -----------------------------------------

# %% [markdown]
# # Problem 2
#
# Simulate the experiment of tossing $1000$ times a coin with probability of **head (coded as $1$) equal to $0.4$** and probability of **tail (coded as $0$) equal to $0.6$**. How can you check if the simulation of the experiment of been running as expected.
#
# **Hint**: Use [matplotlib.pyplot.hist¶
# ](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
toss = np.random.choice([0, 1], size = 1000, p = [0.6, 0.4])
plt.hist(toss)
plt.grid()

# %%
#type your code here:

# %% [markdown]
# # Problem 3: Independence
#
# Use NumPy to create simulations and compute **empirical  probability** for the following outcomes. Compare the results with the **theoretical probability**.
#
# 1. Two fair coin flips produce exactly two heads

# %%
ex = 1000000
toss = np.random.choice([0, 1], size = (ex, 2))
head = np.sum(np.sum(toss == 1, axis=1) == 2)
print(head / ex)
# Out:
# 0.249626

# %%
#type your code here:

# simulate 1 million tests of two fair coin flips


# sums of all tests


# proportion of tests that produced exactly two heads
# Out:
# 0.249809

# %% [markdown]
# 2. Three fair coin flips produce exactly one head

# %%
toss = np.random.choice([0, 1], size = (ex, 3))
head = np.sum(np.sum(toss == 1, axis=1) == 1)
print(head / ex)
# Out:
# 0.3756

# %%
#type your code here:

# simulate 1 million tests of three fair coin flips


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.374819

# %% [markdown]
# 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
toss = np.random.choice([0, 1], size = (ex, 3), p = [0.4, 0.6])
head = np.sum(np.sum(toss == 1, axis=1) == 1)
print(head / ex)
# Out:
# 0.28799

# %%
#type your code here:


# simulate 1 million tests of three biased coin flips
# hint: use np.random.choice()


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.288288

# %% [markdown]
# # Problem 4:Random Variables Statistical Tools
# Simulate Rolling a fair die $1000$ times. Then calculate the following:
#
# - Sample mean
# - Sample variance
# - Sample standard deviation
#
# Compare the results with the theoretical probability.

# %%
sample = np.random.choice([1, 2, 3, 4, 5, 6], 1000)

mean = np.sum(np.arange(1, 7)) / 6
var = np.sum((np.arange(1, 7) - mean) ** 2) / 6
std = np.sqrt(np.sum((np.arange(1, 7) - mean) ** 2) / 6)

print("Sample Mean = ", np.mean(sample))
print("Sample Variance  = ", np.var(sample))
print("Sample Std  = ", np.std(sample))
print("\nTheoritical \n ")
print(f"{mean}")
print(f"{var}")
print(f"{std}")
# Out:
# Sample Mean =  3.524
# Sample Variance  =  2.903424
# Sample Std  =  1.70394366104047
#
# Theoritical
#
# 3.5
# 2.9166666666666665
# 1.707825127659933

# %%
#type your code here:
# Out:
# Sample mean: 3.463
# Sample variance: 3.005636636636637
# Sample standard deviation: 1.7336772008181445
# 3.463
# 3.005636636636637
# 1.7336772008181445

# %% [markdown]
# # Problem 5: Correlation and Covariance
#
# The CSV file includes a hourly/daily summary for Szeged, Hungary area, between 2006 and 2016. After inspecting the data:
#
# - Calculate the covariance and correlation coeffecient between temperature and apparent temperature
# - Calculate the covariance and correlation coeffecient between temperature and humidity

# %%
df = pd.read_csv('weatherHistory.csv')
temperature = df['Temperature (C)'].to_numpy().reshape(-1)
apparant_temp = df['Apparent Temperature (C)'].to_numpy().reshape(-1)
humidity = df['Humidity'].to_numpy().reshape(-1)

# %%
plt.scatter(temperature, apparant_temp)
plt.grid()
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
# Out:
# Text(0, 0.5, 'Apparent Temperature (C)')

# %%
plt.scatter(humidity, temperature)
plt.grid()
plt.xlabel('Humidity')
plt.ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %% [markdown]
# ## Temperature and Apparent Temperature

# %%
print("Covariance = ", np.cov(temperature, apparant_temp)[0, 1])
print('-' * 50)
print("np.cov() :\n", np.cov(temperature, apparant_temp))
print('-' * 50)
print("Correlation Cof: ", np.corrcoef(temperature, apparant_temp)[0, 1])
print('-' * 50)
print("np.corrcoef(): \n", np.corrcoef(temperature, apparant_temp))
# Out:
# Covariance =  101.418283188541
# --------------------------------------------------
# np.cov() :
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# --------------------------------------------------
# Correlation Cof:  0.9926285641920806
# --------------------------------------------------
# np.corrcoef():
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[101.41828319]]
# ---------------------------------------------------
# np.cov():
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# ---------------------------------------------------
# Correlation Cof:  [[0.99262856]]
# ---------------------------------------------------
# np.corrcoef():
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %% [markdown]
# ## Temperature and Humidity

# %%
print("Covariance = ", np.cov(temperature, humidity)[0, 1])
print('-' * 50)
print("np.cov() :\n", np.cov(temperature, humidity))
print('-' * 50)
print("Correlation Cof: ", np.corrcoef(temperature, humidity)[0, 1])
print('-' * 50)
print("np.corrcoef(): \n", np.corrcoef(temperature, humidity))
# Out:
# Covariance =  -1.180461789785137
# --------------------------------------------------
# np.cov() :
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# --------------------------------------------------
# Correlation Cof:  -0.6322546750264326
# --------------------------------------------------
# np.corrcoef():
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[-1.18046179]]
# ---------------------------------------------------
# np.cov():
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# ---------------------------------------------------
# Correlation Cof:  [[-0.63225468]]
# ---------------------------------------------------
# np.corrcoef():
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]
